# %%
import pandas as pd

# %%
df = pd.read_csv('all divisions combined.csv')

# %%
df.shape
# Out:
# (28507, 13)

# %%
df
# Out:
#        Unnamed: 0     Last Name   First Name       Middle M/W  Doubles  Mixed  \
# 0               0         Adams      Michael          NaN   M      2.5    3.0
# 1               1       Addison      Jeffrey          NaN   M      2.5    2.5
# 2               2      Anderson       Sherry          NaN   F      2.5    3.0
# 3               3         Apgar     Mary Ann          NaN   F      2.5    NaN
# 4               4        Aquino         Mike          NaN   M      2.5    NaN
# 5               5        Arnold        Rusty            D   M      2.5    NaN
# 6               6         Ayala     Agustin           NaN   M      2.5    2.5
# 7               7         Ayala      Marlene          NaN   F      2.5    2.5
# 8               8       Babcock       Edward       Eugene   M      2.5    3.0
# 9               9         Bakst         Alan          NaN   M      2.5    NaN
# 10             10         Barns         Sher          NaN   F      2.5    NaN
# ...

# %%
df = df.drop(df.columns[0],axis=1)

# %%
df
# Out:
#           Last Name   First Name       Middle M/W  Doubles  Mixed  Singles  \
# 0             Adams      Michael          NaN   M      2.5    3.0      NaN
# 1           Addison      Jeffrey          NaN   M      2.5    2.5      NaN
# 2          Anderson       Sherry          NaN   F      2.5    3.0      2.5
# 3             Apgar     Mary Ann          NaN   F      2.5    NaN      NaN
# 4            Aquino         Mike          NaN   M      2.5    NaN      NaN
# 5            Arnold        Rusty            D   M      2.5    NaN      NaN
# 6             Ayala     Agustin           NaN   M      2.5    2.5      NaN
# 7             Ayala      Marlene          NaN   F      2.5    2.5      NaN
# 8           Babcock       Edward       Eugene   M      2.5    3.0      NaN
# 9             Bakst         Alan          NaN   M      2.5    NaN      NaN
# 10            Barns         Sher          NaN   F      2.5    NaN      NaN
# ...

# %%
df['M/W'].describe()
# Out:
# count     28506
# unique        3
# top           M
# freq      16681
# Name: M/W, dtype: object

# %%
df['M/W'].value_counts()
# Out:
# M    16681
# F    11815
# X       10
# Name: M/W, dtype: int64

# %%
df['Doubles'].value_counts()
# Out:
# 3.5    9635
# 4.0    7136
# 3.0    5006
# 4.5    3159
# 5.0     997
# 2.5     603
# 5.5     144
# 6.0      21
# Name: Doubles, dtype: int64
